# %%
import pandas as pd #especializada en la manipulación y el análisis de datos
import numpy as np # para crear vectores y matrices grandes multidimensionales
import matplotlib.pyplot as plt #matplotlib generación de gráficos en dos dimensiones
#pyplot Proporciona una forma de representación gráfica implícita, similar a MATLAB. Abre figuras en su pantalla y actúa como el administrador de GUI de figuras.
#import seaborn as sns #interfaz de alto nivel para dibujar gráficos estadísticos atractivos
# %matplotlib inline
import seaborn as sns

# %%
#leer el conjunto de datos
data = pd.read_csv('pima-indians-diabetes.csv') #https://pandas.pydata.org/docs/reference/io.html
pd.options.display.max_columns = 9
data
# Out:
#      nEmbarazos  concentracionGlucosa  presionArterialSistolica  \
# 0             6                   148                        72
# 1             1                    85                        66
# 2             8                   183                        64
# 3             1                    89                        66
# 4             0                   137                        40
# ..          ...                   ...                       ...
# 763          10                   101                        76
# 764           2                   122                        70
# 765           5                   121                        72
# 766           1                   126                        60
# 767           1                    93                        70
#
#      pliegueCutaneo  insulinaSerica   IMC  funcionPediDiabe  edad  diabetes
# 0                35               0  33.6             0.627    50         1
# 1                29               0  26.6             0.351    31         0
# 2                 0               0  23.3             0.672    32         1
# 3                23              94  28.1             0.167    21         0
# 4                35             168  43.1             2.288    33         1
# ..              ...             ...   ...               ...   ...       ...
# 763              48             180  32.9             0.171    63         0
# 764              27               0  36.8             0.340    27         0
# 765              23             112  26.2             0.245    30         0
# 766               0               0  30.1             0.349    47         1
# 767              31               0  30.4             0.315    23         0
#
# [768 rows x 9 columns]

# %%
data.describe()
# Out:
#        nEmbarazos  concentracionGlucosa  presionArterialSistolica  \
# count  768.000000            768.000000                768.000000
# mean     3.845052            120.894531                 69.105469
# std      3.369578             31.972618                 19.355807
# min      0.000000              0.000000                  0.000000
# 25%      1.000000             99.000000                 62.000000
# 50%      3.000000            117.000000                 72.000000
# 75%      6.000000            140.250000                 80.000000
# max     17.000000            199.000000                122.000000
#
#        pliegueCutaneo  insulinaSerica         IMC  funcionPediDiabe  \
# count      768.000000      768.000000  768.000000        768.000000
# mean        20.536458       79.799479   31.992578          0.471876
# std         15.952218      115.244002    7.884160          0.331329
# min          0.000000        0.000000    0.000000          0.078000
# 25%          0.000000        0.000000   27.300000          0.243750
# 50%         23.000000       30.500000   32.000000          0.372500
# 75%         32.000000      127.250000   36.600000          0.626250
# max         99.000000      846.000000   67.100000          2.420000
#
#              edad    diabetes
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
data.hist(column='nEmbarazos')
# Out:
# array([[<AxesSubplot:title={'center':'nEmbarazos'}>]], dtype=object)

# %%
corr = data.corr()
corr
# Out:
#                           nEmbarazos  concentracionGlucosa  \
# nEmbarazos                  1.000000              0.129459
# concentracionGlucosa        0.129459              1.000000
# presionArterialSistolica    0.141282              0.152590
# pliegueCutaneo             -0.081672              0.057328
# insulinaSerica             -0.073535              0.331357
# IMC                         0.017683              0.221071
# funcionPediDiabe           -0.033523              0.137337
# edad                        0.544341              0.263514
# diabetes                    0.221898              0.466581
#
#                           presionArterialSistolica  pliegueCutaneo  \
# nEmbarazos                                0.141282       -0.081672
# concentracionGlucosa                      0.152590        0.057328
# presionArterialSistolica                  1.000000        0.207371
# pliegueCutaneo                            0.207371        1.000000
# insulinaSerica                            0.088933        0.436783
# IMC                                       0.281805        0.392573
# funcionPediDiabe                          0.041265        0.183928
# edad                                      0.239528       -0.113970
# diabetes                                  0.065068        0.074752
#
#                           insulinaSerica       IMC  funcionPediDiabe  \
# nEmbarazos                     -0.073535  0.017683         -0.033523
# concentracionGlucosa            0.331357  0.221071          0.137337
# presionArterialSistolica        0.088933  0.281805          0.041265
# pliegueCutaneo                  0.436783  0.392573          0.183928
# insulinaSerica                  1.000000  0.197859          0.185071
# IMC                             0.197859  1.000000          0.140647
# funcionPediDiabe                0.185071  0.140647          1.000000
# edad                           -0.042163  0.036242          0.033561
# diabetes                        0.130548  0.292695          0.173844
#
#                               edad  diabetes
# nEmbarazos                0.544341  0.221898
# concentracionGlucosa      0.263514  0.466581
# presionArterialSistolica  0.239528  0.065068
# pliegueCutaneo           -0.113970  0.074752
# insulinaSerica           -0.042163  0.130548
# IMC                       0.036242  0.292695
# funcionPediDiabe          0.033561  0.173844
# edad                      1.000000  0.238356
# diabetes                  0.238356  1.000000

# %%
dataplot = sns.heatmap(corr, cmap="YlGnBu", annot=False)
import matplotlib.pyplot as mp

# displaying heatmap
mp.show()

# %%
total_nulls = data.isnull().sum()
total_nulls
# Out:
# nEmbarazos                  0
# concentracionGlucosa        0
# presionArterialSistolica    0
# pliegueCutaneo              0
# insulinaSerica              0
# IMC                         0
# funcionPediDiabe            0
# edad                        0
# diabetes                    0
# dtype: int64

# %%
(data==0).sum(axis=0)
# Out:
# nEmbarazos                  111
# concentracionGlucosa          5
# presionArterialSistolica     35
# pliegueCutaneo              227
# insulinaSerica              374
# IMC                          11
# funcionPediDiabe              0
# edad                          0
# diabetes                    500
# dtype: int64

# %%
filtered = data[(data.concentracionGlucosa < 60) & (data.concentracionGlucosa >= 0)]
filtered["concentracionGlucosa"]
# Out:
# 62     44
# 75      0
# 146    57
# 182     0
# 342     0
# 349     0
# 502     0
# 537    57
# 680    56
# Name: concentracionGlucosa, dtype: int64

# %%
#replace 0 with nan
cols = ["concentracionGlucosa", "presionArterialSistolica", 'pliegueCutaneo', "insulinaSerica", "IMC"]
data[cols] = data[cols].replace({'0':np.nan, 0:np.nan})


#data.replace(0, np.nan, inplace=True)

#count the number of nan values in each column
data.isnull().sum()
# Out:
# nEmbarazos                    0
# concentracionGlucosa          5
# presionArterialSistolica     35
# pliegueCutaneo              227
# insulinaSerica              374
# IMC                          11
# funcionPediDiabe              0
# edad                          0
# diabetes                      0
# dtype: int64

# %%
data
# Out:
#      nEmbarazos  concentracionGlucosa  presionArterialSistolica  \
# 0             6                 148.0                      72.0
# 1             1                  85.0                      66.0
# 2             8                 183.0                      64.0
# 3             1                  89.0                      66.0
# 4             0                 137.0                      40.0
# ..          ...                   ...                       ...
# 763          10                 101.0                      76.0
# 764           2                 122.0                      70.0
# 765           5                 121.0                      72.0
# 766           1                 126.0                      60.0
# 767           1                  93.0                      70.0
#
#      pliegueCutaneo  insulinaSerica   IMC  funcionPediDiabe  edad  diabetes
# 0              35.0             NaN  33.6             0.627    50         1
# 1              29.0             NaN  26.6             0.351    31         0
# 2               NaN             NaN  23.3             0.672    32         1
# 3              23.0            94.0  28.1             0.167    21         0
# 4              35.0           168.0  43.1             2.288    33         1
# ..              ...             ...   ...               ...   ...       ...
# 763            48.0           180.0  32.9             0.171    63         0
# 764            27.0             NaN  36.8             0.340    27         0
# 765            23.0           112.0  26.2             0.245    30         0
# 766             NaN             NaN  30.1             0.349    47         1
# 767            31.0             NaN  30.4             0.315    23         0
#
# [768 rows x 9 columns]
